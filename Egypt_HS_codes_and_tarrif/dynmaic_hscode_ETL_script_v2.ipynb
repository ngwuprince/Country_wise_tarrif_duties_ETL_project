# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

def scrape_customs_data():
    base_url = "https://customs.gov.eg/Services/Tarif?page={}&type=1&chapterId={}"
    data = []

    for chapter in range(1, 4):  # Chapters 1-99
        for page in range(1, 10):   # Pages 1-100 (stops if no data)
            url = base_url.format(page, chapter)
            response = requests.get(url)
            soup = BeautifulSoup(response.text, 'html.parser')

            # Find the table with tariff data
            table = soup.find('table', {'class': 'table'})
            if not table:
                break  # No table found, exit page loop

            rows = table.find_all('tr')[1:]  # Skip header row
            if not rows:
                break  # No data rows, exit page loop

            for row in rows:
                cols = row.find_all('td')
                if len(cols) >= 2:  # Ensure 'Text of the item' and 'Item' exist
                    #text_of_item = cols[1].get_text(strip=True)
                    item = cols[0].get_text(strip=True).replace('/', '')

                    if item:#text_of_item or item  # Only append if data exists
                        data.append({
                            'Chapter': chapter,
                            'Page': page,
                            #'Text of the item': text_of_item,
                            'Item': item
                        })
            print(f"Chapter {chapter}, Page {page} - Scraped {len(rows)} items")

    return pd.DataFrame(data)

# Run the scraper
df_customs = scrape_customs_data()
df_customs.head()
# Out:
# Chapter 1, Page 1 - Scraped 10 items
# Chapter 1, Page 2 - Scraped 10 items
# Chapter 1, Page 3 - Scraped 10 items
# Chapter 1, Page 4 - Scraped 10 items
# Chapter 1, Page 5 - Scraped 7 items
# Chapter 2, Page 1 - Scraped 10 items
# Chapter 2, Page 2 - Scraped 10 items
# Chapter 2, Page 3 - Scraped 10 items
# Chapter 2, Page 4 - Scraped 10 items
# Chapter 2, Page 5 - Scraped 10 items
# Chapter 2, Page 6 - Scraped 10 items
# Chapter 2, Page 7 - Scraped 10 items
# Chapter 2, Page 8 - Scraped 10 items
# Chapter 3, Page 1 - Scraped 10 items
# Chapter 3, Page 2 - Scraped 10 items
# Chapter 3, Page 3 - Scraped 10 items
# Chapter 3, Page 4 - Scraped 10 items
# Chapter 3, Page 5 - Scraped 10 items
# Chapter 3, Page 6 - Scraped 10 items
# Chapter 3, Page 7 - Scraped 10 items
# Chapter 3, Page 8 - Scraped 10 items
# Chapter 3, Page 9 - Scraped 10 items
#    Chapter  Page        Item
# 0        1     1  0101210000
# 1        1     1  0101290000
# 2        1     1  0101300000
# 3        1     1  0101900000
# 4        1     1  0102210000

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_fei_data(hscode):
    # First try with 6-digit code
    hscode_6digit = str(hscode)[:6] if len(str(hscode)) >= 6 else str(hscode)
    result_6digit = scrape_fei_with_code(hscode, hscode_6digit)

    # Check if all fields are N/A
    all_na = all(val == 'N/A' for key, val in result_6digit.items()
                if key not in ['HS_6digit', 'Original_HS_Code'])

    # If all N/A and code is longer than 6 digits, try with full code
    if all_na and len(str(hscode)) > 6:
        print(f"All N/A for 6-digit {hscode_6digit}, trying full code {hscode}")
        result_full = scrape_fei_with_code(hscode, hscode)

        # Only use full code results if we got something better
        if not all(val == 'N/A' for key, val in result_full.items()
                  if key not in ['HS_6digit', 'Original_HS_Code']):
            return result_full

    return result_6digit

def scrape_fei_with_code(original_hscode, lookup_code):
    url = f"http://www.fei.org.eg/tariff/tariff.php?hscode={lookup_code}&keywords=&submit=#"

    try:
        response = requests.get(url, timeout=20)
        soup = BeautifulSoup(response.text, 'html.parser')

        result = {
            'Description': 'N/A',
            'Unit': 'N/A',
            'Custom Fee': 'N/A',
            'VAT': 'N/A',
            'Product Type': 'N/A',
            'Agreement details': 'N/A',
            'HS_6digit': lookup_code[:6] if len(lookup_code) >= 6 else lookup_code,
            'Original_HS_Code': original_hscode
        }

        # EXTRACT DESCRIPTION
        desc_div = soup.find('div', class_='span12 content')
        if desc_div:
            desc_strong = desc_div.find('strong', string='Description: ')
            if desc_strong:
                # Get all text after the Description strong tag
                desc_text = ''.join(desc_strong.find_next_siblings(string=True)).strip()
                result['Description'] = desc_text

        # EXTRACT ALL SPAN6 CONTENT DIVS
        content_divs = soup.find_all('div', class_='span6 content')
        for div in content_divs:
            strong_tag = div.find('strong')
            if strong_tag:
                key = strong_tag.get_text(strip=True).replace(':', '')
                value = ''.join(strong_tag.find_next_siblings(string=True)).strip()

                if key == 'Unit':
                    result['Unit'] = value
                elif key == 'Custom Fee':
                    result['Custom Fee'] = value
                elif key == 'VAT':
                    result['VAT'] = value
                elif key == 'Product Type':
                    result['Product Type'] = value

        # EXTRACT AGREEMENTS
        agreements = []
        try:
            agreements_header = soup.find('p', class_='agree') or soup.find('strong', string='Agreements:')
            if agreements_header:
                agreements_table = agreements_header.find_next('div', class_='row deals')
                if agreements_table:
                    agreement_divs = agreements_table.find_all('div', class_='span6')
                    for i in range(2, len(agreement_divs), 2):
                        if i + 1 < len(agreement_divs):
                            agreement = agreement_divs[i].get_text(strip=True)
                            rate = agreement_divs[i+1].get_text(strip=True)
                            agreements.append(f"{agreement}: {rate}")
                    if agreements:
                        result['Agreement details'] = " | ".join(agreements)
        except Exception as e:
            print(f"Agreement error for {lookup_code}: {str(e)}")

        return result

    except requests.exceptions.RequestException as e:
        print(f"Request failed for {lookup_code}: {str(e)}")
        return {
            'Description': 'ERROR',
            'Unit': 'ERROR',
            'Custom Fee': 'ERROR',
            'VAT': 'ERROR',
            'Product Type': 'ERROR',
            'Agreement details': 'ERROR',
            'HS_6digit': lookup_code[:6] if len(lookup_code) >= 6 else lookup_code,
            'Original_HS_Code': original_hscode
        }

# Assuming df_customs is your input DataFrame containing HS codes in 'Item' column
# FULL PROCESSING
print("\nStarting full scraping with fallback to 10-digit...")
fei_data = []

for i, hscode in enumerate(df_customs['Item'].unique()):
    if i % 10 == 0:
        print(f"Processing {i} of {len(df_customs['Item'].unique())} HS Codes...")
    fei_data.append(scrape_fei_data(hscode))

# CREATE FINAL DATAFRAME
df_fei = pd.DataFrame(fei_data)

# Merge with original data
df_final = pd.merge(
    df_customs,
    df_fei,
    left_on='Item',
    right_on='Original_HS_Code',
    how='left'
).drop(['Original_HS_Code', 'HS_6digit'], axis=1)

# Add quotes around Item values
df_final['Item'] = df_final['Item'].apply(lambda x: f'"{x}"')

# SAVE RESULTS
df_final.to_csv('egyptian_tariff_data_with_fallbacks.csv', index=False, quoting=1)
print("\nScraping complete with fallback logic!")

# Display sample
print("\nSample data:")
df_final.head()
# Out:
# Starting full scraping with fallback to 10-digit...
# Processing 0 of 217 HS Codes...
# Processing 10 of 217 HS Codes...
# Processing 20 of 217 HS Codes...
# Processing 30 of 217 HS Codes...
# Processing 40 of 217 HS Codes...
# Processing 50 of 217 HS Codes...
# Processing 60 of 217 HS Codes...
# All N/A for 6-digit 020450, trying full code 0204500000
# Processing 70 of 217 HS Codes...
# Processing 80 of 217 HS Codes...
# All N/A for 6-digit 020711, trying full code 0207110000
# Processing 90 of 217 HS Codes...
# Processing 100 of 217 HS Codes...
# All N/A for 6-digit 020760, trying full code 0207600010
# All N/A for 6-digit 020760, trying full code 0207600090
# All N/A for 6-digit 020890, trying full code 0208900010
# All N/A for 6-digit 020890, trying full code 0208900090
# Processing 110 of 217 HS Codes...
# All N/A for 6-digit 021091, trying full code 0210910010
# All N/A for 6-digit 021091, trying full code 0210910050
# All N/A for 6-digit 021091, trying full code 0210910090
# All N/A for 6-digit 021092, trying full code 0210920010
# All N/A for 6-digit 021092, trying full code 0210920050
# Processing 120 of 217 HS Codes...
# All N/A for 6-digit 021092, trying full code 0210920090
# All N/A for 6-digit 021093, trying full code 0210930010
# All N/A for 6-digit 021093, trying full code 0210930050
# All N/A for 6-digit 021093, trying full code 0210930090
# All N/A for 6-digit 021099, trying full code 0210990010
# All N/A for 6-digit 021099, trying full code 0210990050
# All N/A for 6-digit 021099, trying full code 0210990090
# Processing 130 of 217 HS Codes...
# Processing 140 of 217 HS Codes...
# Processing 150 of 217 HS Codes...
# Processing 160 of 217 HS Codes...
# Processing 170 of 217 HS Codes...
# All N/A for 6-digit 030299, trying full code 0302990000
# Processing 180 of 217 HS Codes...
# Processing 190 of 217 HS Codes...
# Processing 200 of 217 HS Codes...
# Processing 210 of 217 HS Codes...
#
# Scraping complete with fallback logic!
#
# Sample data:
#    Chapter  Page          Item                    Description      Unit  \
# 0        1     1  "0101210000"     Pure-bred breeding animals  Numrical
# 1        1     1  "0101290000"                Except Purebred  Numrical
# 2        1     1  "0101300000"                          Asses  Numrical
# 3        1     1  "0101900000"                          other  Numrical
# 4        1     1  "0102210000"  -- Pure-bred breeding animals  Numrical
#
#   Custom Fee  VAT      Product Type  \
# 0         5%  N/A  Investment goods
# 1         5%  N/A  Investment goods
# 2         5%  N/A  Investment goods
# 3         5%  N/A  Investment goods
# 4         0%  N/A  Investment goods
#
#                                    Agreement details
# 0  Egypt – EU Association Agreement: Full exempti...
# 1  Egypt – EU Association Agreement: Full exempti...
# 2  Egypt – EU Association Agreement: Full exempti...
# 3  Egypt – EU Association Agreement: Full exempti...
# 4  Egypt – EU Association Agreement: Full exempti...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_fei_data(hscode):
    # First try with 6-digit code
    hscode_6digit = str(hscode)[:6] if len(str(hscode)) >= 6 else str(hscode)
    result_6digit = scrape_fei_with_code(hscode, hscode_6digit)

    # Check conditions for retrying with full code:
    # 1. If all fields are N/A (original condition)
    all_na = all(val == 'N/A' for key, val in result_6digit.items()
                if key not in ['HS_6digit', 'Original_HS_Code'])

    # 2. New condition: If VAT is N/A but other fields have values
    vat_na_but_others_have_data = (
        result_6digit['VAT'] == 'N/A' and
        any(val != 'N/A' for key, val in result_6digit.items()
            if key not in ['HS_6digit', 'Original_HS_Code', 'VAT'])
    )

    # If either condition is met and code is longer than 6 digits, try with full code
    if len(str(hscode)) > 6 and (all_na or vat_na_but_others_have_data):
        print(f"Retrying with full code {hscode} (condition: {'all N/A' if all_na else 'VAT N/A with other data'})")
        result_full = scrape_fei_with_code(hscode, hscode)

        # Only use full code results if we got something better
        if not all(val == 'N/A' for key, val in result_full.items()
                  if key not in ['HS_6digit', 'Original_HS_Code']):
            return result_full
        # If full code returned all N/A, revert to 6-digit results
        else:
            print(f"Full code returned all N/A, reverting to 6-digit results")
            return result_6digit

    return result_6digit

def scrape_fei_with_code(original_hscode, lookup_code):
    url = f"http://www.fei.org.eg/tariff/tariff.php?hscode={lookup_code}&keywords=&submit=#"

    try:
        response = requests.get(url, timeout=20)
        soup = BeautifulSoup(response.text, 'html.parser')

        result = {
            'Description': 'N/A',
            'Unit': 'N/A',
            'Custom Fee': 'N/A',
            'VAT': 'N/A',
            'Product Type': 'N/A',
            'Agreement details': 'N/A',
            'HS_6digit': lookup_code[:6] if len(lookup_code) >= 6 else lookup_code,
            'Original_HS_Code': original_hscode
        }

        # EXTRACT DESCRIPTION
        desc_div = soup.find('div', class_='span12 content')
        if desc_div:
            desc_strong = desc_div.find('strong', string='Description: ')
            if desc_strong:
                # Get all text after the Description strong tag
                desc_text = ''.join(desc_strong.find_next_siblings(string=True)).strip()
                result['Description'] = desc_text

        # EXTRACT ALL SPAN6 CONTENT DIVS
        content_divs = soup.find_all('div', class_='span6 content')
        for div in content_divs:
            strong_tag = div.find('strong')
            if strong_tag:
                key = strong_tag.get_text(strip=True).replace(':', '')
                value = ''.join(strong_tag.find_next_siblings(string=True)).strip()

                if key == 'Unit':
                    result['Unit'] = value
                elif key == 'Custom Fee':
                    result['Custom Fee'] = value
                elif key == 'VAT':
                    result['VAT'] = value
                elif key == 'Product Type':
                    result['Product Type'] = value

        # EXTRACT AGREEMENTS
        agreements = []
        try:
            agreements_header = soup.find('p', class_='agree') or soup.find('strong', string='Agreements:')
            if agreements_header:
                agreements_table = agreements_header.find_next('div', class_='row deals')
                if agreements_table:
                    agreement_divs = agreements_table.find_all('div', class_='span6')
                    for i in range(2, len(agreement_divs), 2):
                        if i + 1 < len(agreement_divs):
                            agreement = agreement_divs[i].get_text(strip=True)
                            rate = agreement_divs[i+1].get_text(strip=True)
                            agreements.append(f"{agreement}: {rate}")
                    if agreements:
                        result['Agreement details'] = " | ".join(agreements)
        except Exception as e:
            print(f"Agreement error for {lookup_code}: {str(e)}")

        return result

    except requests.exceptions.RequestException as e:
        print(f"Request failed for {lookup_code}: {str(e)}")
        return {
            'Description': 'ERROR',
            'Unit': 'ERROR',
            'Custom Fee': 'ERROR',
            'VAT': 'ERROR',
            'Product Type': 'ERROR',
            'Agreement details': 'ERROR',
            'HS_6digit': lookup_code[:6] if len(lookup_code) >= 6 else lookup_code,
            'Original_HS_Code': original_hscode
        }

# Assuming df_customs is your input DataFrame containing HS codes in 'Item' column
# FULL PROCESSING
print("\nStarting full scraping with fallback to 10-digit...")
fei_data = []

for i, hscode in enumerate(df_customs['Item'].unique()):
    if i % 10 == 0:
        print(f"Processing {i} of {len(df_customs['Item'].unique())} HS Codes...")
    fei_data.append(scrape_fei_data(hscode))

# CREATE FINAL DATAFRAME
df_fei = pd.DataFrame(fei_data)

# Merge with original data
df_final = pd.merge(
    df_customs,
    df_fei,
    left_on='Item',
    right_on='Original_HS_Code',
    how='left'
).drop(['Original_HS_Code', 'HS_6digit'], axis=1)

# Add quotes around Item values
df_final['Item'] = df_final['Item'].apply(lambda x: f'"{x}"')

# SAVE RESULTS
df_final.to_csv('egyptian_tariff_data_with_fallb.csv', index=False, quoting=1)
print("\nScraping complete with fallback logic!")

# Display sample
print("\nSample data:")
df_final.head()
# Out:
# Starting full scraping with fallback to 10-digit...
# Processing 0 of 217 HS Codes...
# Retrying with full code 0101210000 (condition: VAT N/A with other data)
# Retrying with full code 0101290000 (condition: VAT N/A with other data)
# Retrying with full code 0101300000 (condition: VAT N/A with other data)
# Retrying with full code 0101900000 (condition: VAT N/A with other data)
# Retrying with full code 0102210000 (condition: VAT N/A with other data)
# Retrying with full code 0102290000 (condition: VAT N/A with other data)
# Retrying with full code 0102310000 (condition: VAT N/A with other data)
# Retrying with full code 0102390000 (condition: VAT N/A with other data)
# Retrying with full code 0102900000 (condition: VAT N/A with other data)
# Retrying with full code 0103100000 (condition: VAT N/A with other data)
# Processing 10 of 217 HS Codes...
# Retrying with full code 0103910000 (condition: VAT N/A with other data)
# Retrying with full code 0103920000 (condition: VAT N/A with other data)
# Retrying with full code 0104100010 (condition: VAT N/A with other data)
# Retrying with full code 0104100090 (condition: VAT N/A with other data)
# Retrying with full code 0104200000 (condition: VAT N/A with other data)
# Retrying with full code 0105110000 (condition: VAT N/A with other data)
# Retrying with full code 0105120000 (condition: VAT N/A with other data)
# Retrying with full code 0105130000 (condition: VAT N/A with other data)
# Retrying with full code 0105140000 (condition: VAT N/A with other data)
# Retrying with full code 0105150000 (condition: VAT N/A with other data)
# Processing 20 of 217 HS Codes...
# Retrying with full code 0105940010 (condition: VAT N/A with other data)
# Retrying with full code 0105940090 (condition: VAT N/A with other data)
# Full code returned all N/A, reverting to 6-digit results
# Retrying with full code 0105990010 (condition: VAT N/A with other data)
# Retrying with full code 0105990090 (condition: VAT N/A with other data)
# Retrying with full code 0106110000 (condition: VAT N/A with other data)
# Retrying with full code 0106120010 (condition: VAT N/A with other data)
# Retrying with full code 0106120090 (condition: VAT N/A with other data)
# Retrying with full code 0106130010 (condition: VAT N/A with other data)
# Retrying with full code 0106130090 (condition: VAT N/A with other data)
# Retrying with full code 0106140010 (condition: VAT N/A with other data)
# Processing 30 of 217 HS Codes...
# Retrying with full code 0106140090 (condition: VAT N/A with other data)
# Retrying with full code 0106190010 (condition: VAT N/A with other data)
# Retrying with full code 0106190090 (condition: VAT N/A with other data)
# Retrying with full code 0106200000 (condition: VAT N/A with other data)
# Retrying with full code 0106310010 (condition: VAT N/A with other data)
# Retrying with full code 0106310090 (condition: VAT N/A with other data)
# Retrying with full code 0106320000 (condition: VAT N/A with other data)
# Retrying with full code 0106330010 (condition: VAT N/A with other data)
# Retrying with full code 0106330090 (condition: VAT N/A with other data)
# Retrying with full code 0106390010 (condition: VAT N/A with other data)
# Processing 40 of 217 HS Codes...
# Retrying with full code 0106390090 (condition: VAT N/A with other data)
# Retrying with full code 0106410000 (condition: VAT N/A with other data)
# Retrying with full code 0106490000 (condition: VAT N/A with other data)
# Retrying with full code 0106900010 (condition: VAT N/A with other data)
# Retrying with full code 0106900030 (condition: VAT N/A with other data)
# Retrying with full code 0106900050 (condition: VAT N/A with other data)
# Retrying with full code 0106900090 (condition: VAT N/A with other data)
# Processing 50 of 217 HS Codes...
# Processing 60 of 217 HS Codes...
# Retrying with full code 0204500000 (condition: all N/A)
# Full code returned all N/A, reverting to 6-digit results
# Retrying with full code 0205000000 (condition: VAT N/A with other data)
# Full code returned all N/A, reverting to 6-digit results
# Processing 70 of 217 HS Codes...
# Processing 80 of 217 HS Codes...
# Retrying with full code 0207110000 (condition: all N/A)
# Full code returned all N/A, reverting to 6-digit results
# Processing 90 of 217 HS Codes...
# Processing 100 of 217 HS Codes...
# Retrying with full code 0207600010 (condition: all N/A)
# Retrying with full code 0207600090 (condition: all N/A)
# Retrying with full code 0208900010 (condition: all N/A)
# Retrying with full code 0208900090 (condition: all N/A)
# Processing 110 of 217 HS Codes...
# Retrying with full code 0210910010 (condition: all N/A)
# Retrying with full code 0210910050 (condition: all N/A)
# Retrying with full code 0210910090 (condition: all N/A)
# Retrying with full code 0210920010 (condition: all N/A)
# Retrying with full code 0210920050 (condition: all N/A)
# Processing 120 of 217 HS Codes...
# Retrying with full code 0210920090 (condition: all N/A)
# Retrying with full code 0210930010 (condition: all N/A)
# Retrying with full code 0210930050 (condition: all N/A)
# Retrying with full code 0210930090 (condition: all N/A)
# Retrying with full code 0210990010 (condition: all N/A)
# Retrying with full code 0210990050 (condition: all N/A)
# Retrying with full code 0210990090 (condition: all N/A)
# Processing 130 of 217 HS Codes...
# Processing 140 of 217 HS Codes...
# Processing 150 of 217 HS Codes...
# Processing 160 of 217 HS Codes...
# Processing 170 of 217 HS Codes...
# Retrying with full code 0302990000 (condition: all N/A)
# Full code returned all N/A, reverting to 6-digit results
# Processing 180 of 217 HS Codes...
# Processing 190 of 217 HS Codes...
# Processing 200 of 217 HS Codes...
# Processing 210 of 217 HS Codes...
#
# Scraping complete with fallback logic!
#
# Sample data:
#    Chapter  Page          Item                             Description  \
# 0        1     1  "0101210000"         Horses, Purebred Breeding, Live
# 1        1     1  "0101290000"  Horses, Live, Except Purebred Breeding
# 2        1     1  "0101300000"                             Asses, Live
# 3        1     1  "0101900000"                 Mules And Hinnies, Live
# 4        1     1  "0102210000"              Cattle, pure-bred breeding
#
#        Unit Custom Fee                                     VAT  \
# 0  Numrical         5%  VAT...0% from the value + customs fees
# 1  Numrical         5%  VAT...0% from the value + customs fees
# 2  Numrical         5%  VAT...0% from the value + customs fees
# 3  Numrical         5%  VAT...0% from the value + customs fees
# 4  Numrical         0%  VAT...0% from the value + customs fees
#
#        Product Type                                  Agreement details
# 0  Investment goods  Egypt – EU Association Agreement: Full exempti...
# 1  Investment goods  Egypt – EU Association Agreement: Full exempti...
# 2  Investment goods  Egypt – EU Association Agreement: Full exempti...
# 3  Investment goods  Egypt – EU Association Agreement: Full exempti...
# 4  Investment goods  Egypt – EU Association Agreement: Full exempti...
